# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix

import pandas as pd
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 150)

# %%
# import required module
import os
import textract, re
 
# assign directory
directory = '/Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications'

documents = pd.DataFrame(columns = ['FileName', 'PageCount', 'WordCount'])
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        print('File Name:', filename.path)
        pdfFileObj = open(filename.path, 'rb')
 
        # creating a pdf reader object
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
 
        # printing number of pages in pdf file
        numPages=pdfReader.numPages
        print('Page Count:', numPages)
        
        word_count_total = 0
        saved_text = []
        for i in range(0, numPages):
            PageObj = pdfReader.getPage(i)
            page_content = PageObj.extractText() 
            saved_text.append(page_content)
            word_count_total+=len(page_content.split())
            
        print('Word Count:', word_count_total)
        documents.append({'FileName':filename,'PageCount':numPages,'WordCount':word_count_total}, ignore_index=True)
        
        # closing the pdf file object
        pdfFileObj.close()
# Out:
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/ARCD.P0684WO - 2020-05-15 - Filed PCT Application.PDF
# Page Count: 78
# Word Count: 952
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/ARCD.P0688WO - 2020-06-03 - Filed PCT Application.PDF
# Page Count: 109
# Word Count: 974
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/UCHI 19-T-149 PCT as Filed.pdf
# Page Count: 79
# Word Count: 940
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/PCT patent application filed.pdf
# Page Count: 41
# Word Count: 0
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/Singh et al. - PCT Application as Filed 08-17-2021; UCHI20-T-077-002; CM 507814.5000430.pdf
# Page Count: 57
# Word Count: 0
# File Name: /Users/amyzhang/Desktop/MScA/Capstone 1/PolskyCapstone/PCT Applications/UOFCAPROVPCTapplication.pdf
# Page Count: 29
# ...

# %%
documents
# Out:
# Empty DataFrame
# Columns: [FileName, PageCount, WordCount]
# Index: []
